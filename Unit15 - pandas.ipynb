# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
print(df)
# Out:
# [                                       Olympic Games
# 0                                        Main topics
# 1  Bids Boycotts Ceremonies Charter Host cities I...
# 2                                              Games
# 3  Summer Winter Youth African American Asian Eur...
# 4                                                vte,                                Unnamed: 0_level_0 Summer Games  \
#                                   Team (IOC code)            №
# 0                               Afghanistan (AFG)           14
# 1                                   Algeria (ALG)           13
# 2                                 Argentina (ARG)           24
# 3                                   Armenia (ARM)            6
# 4                         Australasia (ANZ) [ANZ]            2
# ..                                            ...          ...
# 148                          Zimbabwe (ZIM) [ZIM]           13
# 149      Independent Olympic Athletes (IOA) [IOA]            3
# 150  Independent Olympic Participants (IOP) [IOP]            1
# 151                        Mixed team (ZZX) [ZZX]            3
# 152                                        Totals           28
#
#                                                                      \
#     Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1  Total
# 0                    0                  0                  2      2
# 1                    5                  4                  8     17
# 2                   21                 25                 28     74
# 3                    2                  6                  6     14
# 4                    3                  4                  5     12
# ..                 ...                ...                ...    ...
# 148                  3                  4                  1      8
# 149                  1                  0                  1      2
# 150                  0                  1                  2      3
# 151                  8                  5                  4     17
# 152               5115               5082               5488  15685
#
#     Winter Games                                                           \
#                № Unnamed: 7_level_1 Unnamed: 8_level_1 Unnamed: 9_level_1
# 0              0                  0                  0                  0
# 1              3                  0                  0                  0
# 2             19                  0                  0                  0
# 3              7                  0                  0                  0
# 4              0                  0                  0                  0
# ..           ...                ...                ...                ...
# 148            1                  0                  0                  0
# 149            0                  0                  0                  0
# 150            0                  0                  0                  0
# 151            0                  0                  0                  0
# 152           23               1062               1058               1050
#
#           Combined Total                                          \
#     Total              № Unnamed: 12_level_1 Unnamed: 13_level_1
# 0       0             14                   0                   0
# 1       0             16                   5                   4
# 2       0             43                  21                  25
# 3       0             13                   2                   6
# 4       0              2                   3                   4
# ..    ...            ...                 ...                 ...
# 148     0             14                   3                   4
# 149     0              3                   1                   0
# 150     0              1                   0                   1
# 151     0              3                   8                   5
# 152  3170             51                6177                6140
#
#
#     Unnamed: 14_level_1  Total
# 0                     2      2
# 1                     8     17
# 2                    28     74
# 3                     6     14
# 4                     5     12
# ..                  ...    ...
# 148                   1      8
# 149                   1      2
# 150                   2      3
# 151                   4     17
# 152                6538  18855
#
# [153 rows x 16 columns],                      Team (IOC code)  № Summer  № Winter  № Games
# 0                      Albania (ALB)         8         4       12
# 1               American Samoa (ASA)         8         1        9
# 2                      Andorra (AND)        11        12       23
# 3                       Angola (ANG)         9         0        9
# 4          Antigua and Barbuda (ANT)        10         0       10
# ..                               ...       ...       ...      ...
# 74     Republic of China (ROC) [ROC]         3         0        3
# 75                  Saar (SAA) [SAA]         1         0        1
# 76           North Yemen (YAR) [YAR]         2         0        2
# 77           South Yemen (YMD) [YMD]         1         0        1
# 78  Refugee Olympic Team (ROT) [ROT]         1         0        1
#
# [79 rows x 4 columns],              Unnamed: 0_level_0 Summer Games                     \
#                 Team (IOC code)            № Unnamed: 2_level_1
# 0                 Germany (GER)           16                191
# 1                    Saar (SAA)            1                  0
# 2  United Team of Germany (EUA)            3                 28
# 3            East Germany (GDR)            5                153
# 4            West Germany (FRG)            5                 56
# 5                         Total           25                428
#
#                                               Winter Games                     \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Total            № Unnamed: 7_level_1
# 0                194                230   615           12                 92
# 1                  0                  0     0            0                  0
# 2                 54                 36   118            3                  8
# 3                129                127   409            6                 39
# 4                 67                 81   204            6                 11
# 5                444                474  1346           21                150
#
#                                               Combined Total  \
#   Unnamed: 8_level_1 Unnamed: 9_level_1 Total              №
# 0                 88                 60   240             28
# 1                  0                  0     0              1
# 2                  6                  5    19              6
# 3                 36                 35   110             11
# 4                 15                 13    39             11
# 5                145                113   408             46
#
#
#   Unnamed: 12_level_1 Unnamed: 13_level_1 Unnamed: 14_level_1 Total
# 0                 283                 282                 290   855
# 1                   0                   0                   0     0
# 2                  36                  60                  41   137
# 3                 192                 165                 162   519
# 4                  67                  82                  94   243
# 5                 578                 589                 587  1754  ,     0                                                  1
# 0 NaN  This section does not cite any sources. Please...,                    Unnamed: 0_level_0 Summer Games                     \
#                       Team (IOC code)            № Unnamed: 2_level_1
# 0                        Russia (RUS)            6                148
# 1                Russian Empire (RU1)            3                  1
# 2                  Soviet Union (URS)            9                395
# 3                  Unified Team (EUN)            1                 45
# 4  Olympic Athletes from Russia (OAR)            0                  0
# 5                               Total           19                589
#
#                                               Winter Games                     \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Total            № Unnamed: 7_level_1
# 0                125                153   426            6                 47
# 1                  4                  3     8            0                  0
# 2                319                296  1010            9                 78
# 3                 38                 29   112            1                  9
# 4                  0                  0     0            1                  2
# 5                486                481  1556           17                136
#
#                                               Combined Total  \
#   Unnamed: 8_level_1 Unnamed: 9_level_1 Total              №
# 0                 38                 35   120             12
# 1                  0                  0     0              3
# 2                 57                 59   194             18
# 3                  6                  8    23              2
# 4                  6                  9    17              1
# 5                107                111   354             36
#
#
#   Unnamed: 12_level_1 Unnamed: 13_level_1 Unnamed: 14_level_1 Total
# 0                 195                 163                 188   546
# 1                   1                   4                   3     8
# 2                 473                 376                 355  1204
# 3                  54                  44                  37   135
# 4                   2                   6                   9    17
# 5                 725                 593                 592  1910  ,                        Unnamed: 0_level_0 Summer Games                     \
#                           Team (IOC code)            № Unnamed: 2_level_1
# 0                            Serbia (SRB)            4                  3
# 1                        Yugoslavia (YUG)           16                 26
# 2  Independent Olympic Participants (IOP)            1                  0
# 3             Serbia and Montenegro (SCG)            3                  2
# 4                                   Total           24                 31
#
#                                               Winter Games                     \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Total            № Unnamed: 7_level_1
# 0                  6                  6    15            3                  0
# 1                 29                 28    83           13                  0
# 2                  1                  2     3            0                  0
# 3                  4                  3     9            3                  0
# 4                 40                 39   110           19                  0
#
#                                               Combined Total  \
#   Unnamed: 8_level_1 Unnamed: 9_level_1 Total              №
# 0                  0                  0     0              7
# 1                  3                  1     4             29
# 2                  0                  0     0              1
# 3                  0                  0     0              6
# 4                  3                  1     4             43
#
#
#   Unnamed: 12_level_1 Unnamed: 13_level_1 Unnamed: 14_level_1 Total
# 0                   3                   6                   6    15
# 1                  26                  32                  29    87
# 2                   0                   1                   2     3
# 3                   2                   4                   3     9
# 4                  31                  43                  40   114  ,    No.               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)  1022     795     706   2523
# 1    2         Russia (RUS)   589     486     481   1556
# 2    3        Germany (GER)   428     444     474   1346
# 3    4  Great Britain (GBR)   263     295     293    851
# 4    5          China (CHN)   224     167     155    546
# 5    6         France (FRA)   212     241     263    716
# 6    7          Italy (ITA)   206     178     193    577
# 7    8        Hungary (HUN)   175     147     169    491
# 8    9      Australia (AUS)   147     163     187    497
# 9   10         Sweden (SWE)   145     170     179    494,    No.               Nation  Gold  Silver  Bronze  Total
# 0    1        Germany (GER)   150     145     113    408
# 1    2         Russia (RUS)   136     107     111    354
# 2    3         Norway (NOR)   132     125     111    368
# 3    4  United States (USA)   105     112      88    305
# 4    5         Canada (CAN)    73      64      62    199
# 5    6        Austria (AUT)    64      81      87    232
# 6    7         Sweden (SWE)    57      46      55    158
# 7    8    Switzerland (SUI)    55      46      52    153
# 8    9    Netherlands (NED)    45      44      41    130
# 9   10        Finland (FIN)    43      63      61    167,    No.               Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)  1127     907     794   2828
# 1    2         Russia (RUS)   725     593     592   1910
# 2    3        Germany (GER)   578     589     587   1754
# 3    4  Great Britain (GBR)   274     299     310    883
# 4    5         France (FRA)   248     276     316    840
# 5    6          Italy (ITA)   246     214     241    701
# 6    7          China (CHN)   237     195     176    608
# 7    8         Sweden (SWE)   202     216     234    652
# 8    9         Norway (NOR)   188     174     158    520
# 9   10        Hungary (HUN)   176     149     173    498,                                                    0  \
# 0  ANZ → AUS , NZL Australasia (ANZ) was a combin...
#
#                                                    1
# 0  SRB , YUG , SCG Serbia (SRB, 1912, 2006–curren...  ,                                                    0  \
# 0  BIZ Belize participated under its former name ...
#
#                                                    1
# 0  GHA Prior to Ghana's independence in 1957, Gol...  ,                                                    0  \
# 0  A Brunei's participation in the 1988 Games con...
#
#                                                    1
# 0  F India's athletes originally competed at the ...  ,                                                    0  \
# 0  H The Bulgarian Olympic Committee claims that ...
#
#                                                    1
# 0  The nationalities of many medalists at the 190...  ,                        vteOlympic Games medal tables  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                      vteOlympic Games medal tables.1
# 0  Olympic medal All-time Olympic Games medal tab...
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3  Lists of Olympic medalists List of stripped Ol...  ,                       vteOlympic Games medal winners  \
# 0  Olympic medal All-time Olympic Games medal tab...
# 1                               Summer Olympic Games
# 2                               Winter Olympic Games
# 3  Lists of Olympic medalists List of stripped Ol...
#
#                     vteOlympic Games medal winners.1
# 0  Olympic medal All-time Olympic Games medal tab...
# 1  1896 1900 1904 1908 1912 1920 1924 1928 1932 1...
# 2  1924 1928 1932 1936 1948 1952 1956 1960 1964 1...
# 3  Lists of Olympic medalists List of stripped Ol...  ,                        vteLists of Olympic medalists  \
# 0                                      Summer sports
# 1                                      Winter sports
# 2                                Discontinued sports
# 3                                  Unofficial sports
# 4  Olympic sports Olympic medal All-time Olympic ...
#
#                      vteLists of Olympic medalists.1
# 0  Archery Athletics men women Badminton Basketba...
# 1  Alpine skiing Biathlon Bobsleigh Cross-country...
# 2  Baseball Basque pelota Cricket Croquet Jeu de ...
# 3                                   Art competitions
# 4  Olympic sports Olympic medal All-time Olympic ...  ,                                     vteOlympic Games  \
# 0  Ceremonies People who opened the Olympics Keep...
# 1                                        SummerGames
# 2                                       Winter Games
# 3  Ancient Olympic Games Intercalated Games 1906 ...
#
#                                   vteOlympic Games.1  \
# 0  Ceremonies People who opened the Olympics Keep...
# 1  1896 Athens 1900 Paris 1904 St. Louis 1908 Lon...
# 2  1924 Chamonix 1928 St. Moritz 1932 Lake Placid...
# 3  Ancient Olympic Games Intercalated Games 1906 ...
#
#                                   vteOlympic Games.2
# 0  Ceremonies People who opened the Olympics Keep...
# 1                                                NaN
# 2                                                NaN
# 3  Ancient Olympic Games Intercalated Games 1906 ...  ,   vteOlympics and Paralympics statistics  \
# 0             Medalists and medal tables
# 1                     Multiple medalists
# 2                Multiple gold medalists
# 3                       Other statistics
#
#             vteOlympics and Paralympics statistics.1
# 0  Lists of Olympic medalists Lists of Paralympic...
# 1  Multiple Olympic medalists at a single Games i...
# 2  Multiple Olympic gold medalists at a single Ga...
# 3  Olympic medals in different sports at Summer a...  ,       vteSummer Olympics medal table leaders by year  \
# 0  1896: United States 1900: France 1904: United ...
#
#     vteSummer Olympics medal table leaders by year.1
# 0  1896: United States 1900: France 1904: United ...  ,       vteWinter Olympics medal table leaders by year  \
# 0  1924: Norway 1928: Norway 1932: United States ...
#
#     vteWinter Olympics medal table leaders by year.1
# 0  1924: Norway 1928: Norway 1932: United States ...  ,   vteMedal tables of Olympics, Paralympics and World Championships by sport  \
# 0                      Olympic Games(Hosts · Medals)
# 1                   Paralympic Games(Hosts · Medals)
# 2                     WorldChampionshipsorWorld Cups
# 3  List of international rankings List of top int...
#
#   vteMedal tables of Olympics, Paralympics and World Championships by sport.1
# 0  Alpine skiing Archery Athletics Badminton Band...
# 1  Alpine skiing Archery Athletics Biathlon Bocci...
# 2  Alpine skiing American football Aquatics Arche...
# 3  List of international rankings List of top int...                           ]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
df[1]
# Out:
#                                Unnamed: 0_level_0 Summer Games  \
#                                   Team (IOC code)            №
# 0                               Afghanistan (AFG)           14
# 1                                   Algeria (ALG)           13
# 2                                 Argentina (ARG)           24
# 3                                   Armenia (ARM)            6
# 4                         Australasia (ANZ) [ANZ]            2
# ..                                            ...          ...
# 148                          Zimbabwe (ZIM) [ZIM]           13
# 149      Independent Olympic Athletes (IOA) [IOA]            3
# 150  Independent Olympic Participants (IOP) [IOP]            1
# 151                        Mixed team (ZZX) [ZZX]            3
# 152                                        Totals           28
#
#                                                                      \
#     Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1  Total
# 0                    0                  0                  2      2
# 1                    5                  4                  8     17
# 2                   21                 25                 28     74
# 3                    2                  6                  6     14
# 4                    3                  4                  5     12
# ..                 ...                ...                ...    ...
# 148                  3                  4                  1      8
# 149                  1                  0                  1      2
# 150                  0                  1                  2      3
# 151                  8                  5                  4     17
# 152               5115               5082               5488  15685
#
#     Winter Games                                                           \
#                № Unnamed: 7_level_1 Unnamed: 8_level_1 Unnamed: 9_level_1
# 0              0                  0                  0                  0
# 1              3                  0                  0                  0
# 2             19                  0                  0                  0
# 3              7                  0                  0                  0
# 4              0                  0                  0                  0
# ..           ...                ...                ...                ...
# 148            1                  0                  0                  0
# 149            0                  0                  0                  0
# 150            0                  0                  0                  0
# 151            0                  0                  0                  0
# 152           23               1062               1058               1050
#
#           Combined Total                                          \
#     Total              № Unnamed: 12_level_1 Unnamed: 13_level_1
# 0       0             14                   0                   0
# 1       0             16                   5                   4
# 2       0             43                  21                  25
# 3       0             13                   2                   6
# 4       0              2                   3                   4
# ..    ...            ...                 ...                 ...
# 148     0             14                   3                   4
# 149     0              3                   1                   0
# 150     0              1                   0                   1
# 151     0              3                   8                   5
# 152  3170             51                6177                6140
#
#
#     Unnamed: 14_level_1  Total
# 0                     2      2
# 1                     8     17
# 2                    28     74
# 3                     6     14
# 4                     5     12
# ..                  ...    ...
# 148                   1      8
# 149                   1      2
# 150                   2      3
# 151                   4     17
# 152                6538  18855
#
# [153 rows x 16 columns]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=0, index_col=0)
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5115.0
#
#                                               Summer Games.2  Summer Games.3  \
# Team (IOC code)                                          NaN             NaN
# Afghanistan (AFG)                                        0.0             2.0
# Algeria (ALG)                                            4.0             8.0
# Argentina (ARG)                                         25.0            28.0
# Armenia (ARM)                                            6.0             6.0
# ...                                                      ...             ...
# Zimbabwe (ZIM) [ZIM]                                     4.0             1.0
# Independent Olympic Athletes (IOA) [IOA]                 0.0             1.0
# Independent Olympic Participants (IOP) [IOP]             1.0             2.0
# Mixed team (ZZX) [ZZX]                                   5.0             4.0
# Totals                                                5082.0          5488.0
#
#                                              Summer Games.4 Winter Games  \
# Team (IOC code)                                       Total            №
# Afghanistan (AFG)                                         2            0
# Algeria (ALG)                                            17            3
# Argentina (ARG)                                          74           19
# Armenia (ARM)                                            14            7
# ...                                                     ...          ...
# Zimbabwe (ZIM) [ZIM]                                      8            1
# Independent Olympic Athletes (IOA) [IOA]                  2            0
# Independent Olympic Participants (IOP) [IOP]              3            0
# Mixed team (ZZX) [ZZX]                                   17            0
# Totals                                                15685           23
#
#                                               Winter Games.1  Winter Games.2  \
# Team (IOC code)                                          NaN             NaN
# Afghanistan (AFG)                                        0.0             0.0
# Algeria (ALG)                                            0.0             0.0
# Argentina (ARG)                                          0.0             0.0
# Armenia (ARM)                                            0.0             0.0
# ...                                                      ...             ...
# Zimbabwe (ZIM) [ZIM]                                     0.0             0.0
# Independent Olympic Athletes (IOA) [IOA]                 0.0             0.0
# Independent Olympic Participants (IOP) [IOP]             0.0             0.0
# Mixed team (ZZX) [ZZX]                                   0.0             0.0
# Totals                                                1062.0          1058.0
#
#                                               Winter Games.3 Winter Games.4  \
# Team (IOC code)                                          NaN          Total
# Afghanistan (AFG)                                        0.0              0
# Algeria (ALG)                                            0.0              0
# Argentina (ARG)                                          0.0              0
# Armenia (ARM)                                            0.0              0
# ...                                                      ...            ...
# Zimbabwe (ZIM) [ZIM]                                     0.0              0
# Independent Olympic Athletes (IOA) [IOA]                 0.0              0
# Independent Olympic Participants (IOP) [IOP]             0.0              0
# Mixed team (ZZX) [ZZX]                                   0.0              0
# Totals                                                1050.0           3170
#
#                                              Combined Total  Combined Total.1  \
# Team (IOC code)                                           №               NaN
# Afghanistan (AFG)                                        14               0.0
# Algeria (ALG)                                            16               5.0
# Argentina (ARG)                                          43              21.0
# Armenia (ARM)                                            13               2.0
# ...                                                     ...               ...
# Zimbabwe (ZIM) [ZIM]                                     14               3.0
# Independent Olympic Athletes (IOA) [IOA]                  3               1.0
# Independent Olympic Participants (IOP) [IOP]              1               0.0
# Mixed team (ZZX) [ZZX]                                    3               8.0
# Totals                                                   51            6177.0
#
#                                               Combined Total.2  \
# Team (IOC code)                                            NaN
# Afghanistan (AFG)                                          0.0
# Algeria (ALG)                                              4.0
# Argentina (ARG)                                           25.0
# Armenia (ARM)                                              6.0
# ...                                                        ...
# Zimbabwe (ZIM) [ZIM]                                       4.0
# Independent Olympic Athletes (IOA) [IOA]                   0.0
# Independent Olympic Participants (IOP) [IOP]               1.0
# Mixed team (ZZX) [ZZX]                                     5.0
# Totals                                                  6140.0
#
#                                               Combined Total.3  \
# Team (IOC code)                                            NaN
# Afghanistan (AFG)                                          2.0
# Algeria (ALG)                                              8.0
# Argentina (ARG)                                           28.0
# Armenia (ARM)                                              6.0
# ...                                                        ...
# Zimbabwe (ZIM) [ZIM]                                       1.0
# Independent Olympic Athletes (IOA) [IOA]                   1.0
# Independent Olympic Participants (IOP) [IOP]               2.0
# Mixed team (ZZX) [ZZX]                                     4.0
# Totals                                                  6538.0
#
#                                              Combined Total.4
# Team (IOC code)                                         Total
# Afghanistan (AFG)                                           2
# Algeria (ALG)                                              17
# Argentina (ARG)                                            74
# Armenia (ARM)                                              14
# ...                                                       ...
# Zimbabwe (ZIM) [ZIM]                                        8
# Independent Olympic Athletes (IOA) [IOA]                    2
# Independent Olympic Participants (IOP) [IOP]                3
# Mixed team (ZZX) [ZZX]                                     17
# Totals                                                  18855
#
# [154 rows x 15 columns]

# %%
summer = df[1].iloc[:,:5]
summer
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5115.0
#
#                                               Summer Games.2  Summer Games.3  \
# Team (IOC code)                                          NaN             NaN
# Afghanistan (AFG)                                        0.0             2.0
# Algeria (ALG)                                            4.0             8.0
# Argentina (ARG)                                         25.0            28.0
# Armenia (ARM)                                            6.0             6.0
# ...                                                      ...             ...
# Zimbabwe (ZIM) [ZIM]                                     4.0             1.0
# Independent Olympic Athletes (IOA) [IOA]                 0.0             1.0
# Independent Olympic Participants (IOP) [IOP]             1.0             2.0
# Mixed team (ZZX) [ZZX]                                   5.0             4.0
# Totals                                                5082.0          5488.0
#
#                                              Summer Games.4
# Team (IOC code)                                       Total
# Afghanistan (AFG)                                         2
# Algeria (ALG)                                            17
# Argentina (ARG)                                          74
# Armenia (ARM)                                            14
# ...                                                     ...
# Zimbabwe (ZIM) [ZIM]                                      8
# Independent Olympic Athletes (IOA) [IOA]                  2
# Independent Olympic Participants (IOP) [IOP]              3
# Mixed team (ZZX) [ZZX]                                   17
# Totals                                                15685
#
# [154 rows x 5 columns]

# %%
summer.columns = ['경기수', '금', '은', '동', '계']
print(summer)
# Out:
#                                              경기수       금       은       동  \
# Team (IOC code)                                №     NaN     NaN     NaN
# Afghanistan (AFG)                             14     0.0     0.0     2.0
# Algeria (ALG)                                 13     5.0     4.0     8.0
# Argentina (ARG)                               24    21.0    25.0    28.0
# Armenia (ARM)                                  6     2.0     6.0     6.0
# ...                                           ..     ...     ...     ...
# Zimbabwe (ZIM) [ZIM]                          13     3.0     4.0     1.0
# Independent Olympic Athletes (IOA) [IOA]       3     1.0     0.0     1.0
# Independent Olympic Participants (IOP) [IOP]   1     0.0     1.0     2.0
# Mixed team (ZZX) [ZZX]                         3     8.0     5.0     4.0
# Totals                                        28  5115.0  5082.0  5488.0
#
#                                                   계
# Team (IOC code)                               Total
# Afghanistan (AFG)                                 2
# Algeria (ALG)                                    17
# Argentina (ARG)                                  74
# Armenia (ARM)                                    14
# ...                                             ...
# Zimbabwe (ZIM) [ZIM]                              8
# Independent Olympic Athletes (IOA) [IOA]          2
# Independent Olympic Participants (IOP) [IOP]      3
# Mixed team (ZZX) [ZZX]                           17
# Totals                                        15685
#
# [154 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
header=0, index_col=0)
summer = df[1].iloc[:,:5]
summer.columns = ['경기수', '금', '은', '동', '계']
print(summer.sort_values('금', ascending=False))
# Out:
#                                         경기수       금       은       동      계
# Totals                                   28  5115.0  5082.0  5488.0  15685
# United States (USA) [P] [Q] [R] [Z] [F]  27  1022.0   795.0   706.0   2523
# Soviet Union (URS) [URS]                  9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]            28   263.0   295.0   293.0    851
# China (CHN) [CHN]                        10   224.0   167.0   155.0    546
# ...                                      ..     ...     ...     ...    ...
# Eritrea (ERI)                             5     0.0     0.0     1.0      1
# Serbia and Montenegro (SCG) [SCG]         1     0.0     2.0     0.0      2
# Djibouti (DJI) [B]                        8     0.0     0.0     1.0      1
# Afghanistan (AFG)                        14     0.0     0.0     2.0      2
# Team (IOC code)                           №     NaN     NaN     NaN  Total
#
# [154 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
header=0, index_col=0)
summer = df[1].iloc[:,:5]
summer.columns = ['경기수', '금', '은', '동', '계']
print(summer.sort_values('은', ascending=False))
# Out:
#                                         경기수       금       은       동      계
# Totals                                   28  5115.0  5082.0  5488.0  15685
# United States (USA) [P] [Q] [R] [Z] [F]  27  1022.0   795.0   706.0   2523
# Soviet Union (URS) [URS]                  9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]            28   263.0   295.0   293.0    851
# France (FRA) [O] [P] [Z]                 28   212.0   241.0   263.0    716
# ...                                      ..     ...     ...     ...    ...
# North Macedonia (MKD)                     6     0.0     0.0     1.0      1
# Bermuda (BER)                            18     0.0     0.0     1.0      1
# Panama (PAN)                             17     1.0     0.0     2.0      3
# Afghanistan (AFG)                        14     0.0     0.0     2.0      2
# Team (IOC code)                           №     NaN     NaN     NaN  Total
#
# [154 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',
header=0, index_col=0)
summer = df[1].iloc[:,:5]
summer.columns = ['경기수', '금', '은', '동', '계']
print(summer.sort_values('금', ascending=False))
summer.sort_values('금', ascending=False).to_excel('하계올림픽메달.xlsx')
# Out:
#                                         경기수       금       은       동      계
# Totals                                   28  5115.0  5082.0  5488.0  15685
# United States (USA) [P] [Q] [R] [Z] [F]  27  1022.0   795.0   706.0   2523
# Soviet Union (URS) [URS]                  9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]            28   263.0   295.0   293.0    851
# China (CHN) [CHN]                        10   224.0   167.0   155.0    546
# ...                                      ..     ...     ...     ...    ...
# Eritrea (ERI)                             5     0.0     0.0     1.0      1
# Serbia and Montenegro (SCG) [SCG]         1     0.0     2.0     0.0      2
# Djibouti (DJI) [B]                        8     0.0     0.0     1.0      1
# Afghanistan (AFG)                        14     0.0     0.0     2.0      2
# Team (IOC code)                           №     NaN     NaN     NaN  Total
#
# [154 rows x 5 columns]

# %%
import pandas as pd
index = pd.date_range('1/1/2000', periods=8)
print(index)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df
# Out:
#                    A         B         C
# 2000-01-01  0.487280  0.711363  0.447451
# 2000-01-02  0.475198  0.337502  0.632574
# 2000-01-03  0.687771  0.933883  0.101620
# 2000-01-04  0.495288  0.394728  0.001694
# 2000-01-05  0.724462  0.494105  0.059642
# 2000-01-06  0.526155  0.224225  0.790937
# 2000-01-07  0.741058  0.534143  0.969495
# 2000-01-08  0.160879  0.956197  0.241866

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df
# Out:
#                    A         B         C
# 2000-01-01  0.830171  0.404706  0.806362
# 2000-01-02  0.960494  0.539349  0.852755
# 2000-01-03  0.153311  0.595957  0.759018
# 2000-01-04  0.757441  0.304669  0.713827
# 2000-01-05  0.570947  0.066288  0.550931
# 2000-01-06  0.741019  0.809495  0.804365
# 2000-01-07  0.904000  0.400120  0.817155
# 2000-01-08  0.165436  0.215797  0.664957

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
print(df['B'])
# Out:
# 2000-01-01    0.296959
# 2000-01-02    0.433925
# 2000-01-03    0.603755
# 2000-01-04    0.316707
# 2000-01-05    0.346401
# 2000-01-06    0.460690
# 2000-01-07    0.071857
# 2000-01-08    0.727484
# Freq: D, Name: B, dtype: float64

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
print(df['B'] > 0.4)
# Out:
# 2000-01-01    False
# 2000-01-02     True
# 2000-01-03     True
# 2000-01-04     True
# 2000-01-05    False
# 2000-01-06     True
# 2000-01-07    False
# 2000-01-08     True
# Freq: D, Name: B, dtype: bool

# %%
df2 = df[df['B'] > 0.4]
df2
# Out:
#                    A         B         C
# 2000-01-02  0.516285  0.415212  0.711761
# 2000-01-03  0.667026  0.890146  0.145278
# 2000-01-04  0.661740  0.499645  0.642567
# 2000-01-06  0.726593  0.734169  0.093173
# 2000-01-08  0.284278  0.594729  0.366082

# %%
df2 = df[df['B'] > 0.4]
df2.T
# Out:
#    2000-01-02  2000-01-03  2000-01-04  2000-01-06  2000-01-08
# A    0.516285    0.667026    0.661740    0.726593    0.284278
# B    0.415212    0.890146    0.499645    0.734169    0.594729
# C    0.711761    0.145278    0.642567    0.093173    0.366082

# %%
import pandas as pd
import numpy as np
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] / df['B']  # A열의 값을 B열의 값으로 나눈 값을 D열에 저장
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.897822  0.869210  0.326682  1.032917
# 2000-01-02  0.877340  0.785491  0.938324  1.116931
# 2000-01-03  0.900991  0.515282  0.660312  1.748541
# 2000-01-04  0.947652  0.330928  0.811517  2.863621
# 2000-01-05  0.485496  0.759054  0.197958  0.639607
# 2000-01-06  0.839348  0.510050  0.765748  1.645620
# 2000-01-07  0.398977  0.382401  0.397181  1.043347
# 2000-01-08  0.850718  0.784216  0.431330  1.084801

# %%
import pandas as pd
import numpy as np
 
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis=1)  # 행 우선 계산 값을 E열에 저장
df.head()
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.345708  0.185517  0.758653  1.863477  3.153355
# 2000-01-02  0.234433  0.621806  0.726319  0.377020  1.959578
# 2000-01-03  0.139556  0.571041  0.158784  0.244390  1.113771
# 2000-01-04  0.626648  0.452265  0.511435  1.385578  2.975926
# 2000-01-05  0.890988  0.535134  0.788546  1.664983  3.879652

# %%
import pandas as pd
import numpy as np
 
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis=1)
df = df.sub(df['A'], axis=0)  # A열의 데이터를 기준으로 열 우선 계산
df.head()
# Out:
#               A         B         C         D         E
# 2000-01-01  0.0 -0.210916 -0.617750  0.705114  2.018664
# 2000-01-02  0.0  0.109780  0.043173  0.011609  2.796037
# 2000-01-03  0.0  0.405318 -0.012247  0.131818  1.253732
# 2000-01-04  0.0  0.082810  0.443340  0.366231  2.359172
# 2000-01-05  0.0 -0.516360 -0.763184  1.880834  3.061167

# %%
import pandas as pd
import numpy as np
 
index = pd.date_range('1/1/2000', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('ABC'))
df['D'] = df['A'] / df['B']
df['E'] = np.sum(df, axis=1)
df = df.sub(df['A'], axis=0)
df = df.div(df['C'], axis=0)    # C열 데이터를 기준으로 열 우선 계산
df.to_csv('test.csv')           # 데이터 프레임을 test.csv 파일로 저장
df.head()
# Out:
#               A          B    C          D           E
# 2000-01-01 -0.0  -0.346112  1.0  -0.672635   -3.234907
# 2000-01-02 -0.0 -30.052056  1.0 -22.709689 -126.678730
# 2000-01-03 -0.0   0.803067  1.0  -6.564994  -10.182833
# 2000-01-04  0.0  -0.300979  1.0   2.982896    5.548647
# 2000-01-05  0.0   0.789235  1.0   0.124672    2.870190

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col=0)
df.head()
# Out:
#                                 총인구수  연령구간인구수     0세     1세     2세     3세  \
# 행정구역
# 서울특별시  (1100000000)          9724496  9724496  47776  53356  56588  61977
# 서울특별시 종로구 (1111000000)        150623   150623    570    576    642    746
# 서울특별시 종로구 청운효자동(1111051500)    12667    12667     71     64     67     86
# 서울특별시 종로구 사직동(1111053000)       9481     9481     31     37     45     59
# 서울특별시 종로구 삼청동(1111054000)       2718     2718      5      7     13      8
#
#                                 4세     5세     6세     7세  ...   91세   92세  \
# 행정구역                                                     ...
# 서울특별시  (1100000000)          68513  69595  68383  73751  ...  8272  6334
# 서울특별시 종로구 (1111000000)         834    840    846    985  ...   203   129
# 서울특별시 종로구 청운효자동(1111051500)     81    103     91     99  ...    13     4
# 서울특별시 종로구 사직동(1111053000)       64     76     70     82  ...    22    10
# 서울특별시 종로구 삼청동(1111054000)       13     10     12     13  ...     2     7
#
#                               93세   94세   95세   96세   97세   98세   99세  100세 이상
# 행정구역
# 서울특별시  (1100000000)          4821  3382  2501  2159  2021  1394  1000     6511
# 서울특별시 종로구 (1111000000)        122   100    72    62    60    57    32      267
# 서울특별시 종로구 청운효자동(1111051500)     8     9     7     8     6     4     2       19
# 서울특별시 종로구 사직동(1111053000)       9    14     5     2     8     1     3       19
# 서울특별시 종로구 삼청동(1111054000)       4     1     2     1     3     0     1        8
#
# [5 rows x 103 columns]

# %%
import pandas as pd
df = pd.read_csv('age.csv', encoding='cp949', index_col=0)
df = df.div(df['총인구수'], axis=0) # 1 │ ➊ 전체 데이터를 총인구수로 나눠서 비율로 변환
del df['총인구수'], df['연령구간인구수']  # 1 │ ➋ 총인구수, 연령구간인구수 열 삭제

# %%
name = input('원하는 지역의 이름을 입력해주세요 : ')  # 2 │ 지역 이름 입력
a = df.index.str.contains(name)  # 3 │ 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]
df2
# Out:
# 원하는 지역의 이름을 입력해주세요 : 화양동
#                                  0세        1세        2세        3세        4세  \
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.001883  0.001435  0.001659  0.001883  0.001972
#
#                                  5세        6세        7세        8세      9세  \
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.002466  0.001928  0.001928  0.001838  0.0026
#
#                            ...       91세       92세       93세       94세  \
# 행정구역                       ...
# 서울특별시 광진구 화양동(1121571000)  ...  0.000493  0.000359  0.000269  0.000224
#
#                                 95세       96세      97세       98세      99세  \
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.000314  0.000179  0.00009  0.000134  0.00009
#
#                             100세 이상
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.000986
#
# [1 rows x 101 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df2.T.plot()
plt.show()

# %%
import numpy as np
# 4 │ ➊ 궁금한 지역 A의 인구 비율에서 B의 인구 비율을 뺀다.
x = df.sub(df2.iloc[0], axis=1)
# 4 │ ➋ A의 인구 비율에서 B의 인구 비율을 뺀 값의 제곱 값을 모두 더한다.
y = np.power(x, 2)
z = y.sum(axis=1)

# %%
i = z.sort_values().index[:5]  # 4 │ ➌ 그 차이가 가장 작은 지역 5곳을 찾는다.

# %%
df.loc[i].T.plot()   # 4 │ ➍ 결과를 꺾은선 그래프로 보여준다.
plt.show()

# %%
df2
# Out:
#                                  0세        1세        2세        3세        4세  \
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.001883  0.001435  0.001659  0.001883  0.001972
#
#                                  5세        6세        7세        8세      9세  \
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.002466  0.001928  0.001928  0.001838  0.0026
#
#                            ...       91세       92세       93세       94세  \
# 행정구역                       ...
# 서울특별시 광진구 화양동(1121571000)  ...  0.000493  0.000359  0.000269  0.000224
#
#                                 95세       96세      97세       98세      99세  \
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.000314  0.000179  0.00009  0.000134  0.00009
#
#                             100세 이상
# 행정구역
# 서울특별시 광진구 화양동(1121571000)  0.000986
#
# [1 rows x 101 columns]

# %%
x
# Out:
#                                     0세        1세        2세        3세  \
# 행정구역
# 서울특별시  (1100000000)           0.003030  0.004052  0.004160  0.004490
# 서울특별시 종로구 (1111000000)        0.001901  0.002390  0.002604  0.003070
# 서울특별시 종로구 청운효자동(1111051500)   0.003722  0.003618  0.003631  0.004906
# 서울특별시 종로구 사직동(1111053000)     0.001387  0.002468  0.003088  0.004340
# 서울특별시 종로구 삼청동(1111054000)    -0.000043  0.001141  0.003124  0.001061
# ...                                ...       ...       ...       ...
# 제주특별자치도 서귀포시 서홍동(5013058000)  0.004919  0.006517  0.006580  0.008464
# 제주특별자치도 서귀포시 대륜동(5013059000)  0.008140  0.008588  0.007673  0.010559
# 제주특별자치도 서귀포시 대천동(5013060000)  0.006946  0.007466  0.009992  0.012807
# 제주특별자치도 서귀포시 중문동(5013061000)  0.004743  0.005888  0.004095  0.005004
# 제주특별자치도 서귀포시 예래동(5013062000)  0.001938  0.006716  0.001398  0.005249
#
#                                     4세        5세        6세        7세  \
# 행정구역
# 서울특별시  (1100000000)           0.005073  0.004691  0.005104  0.005656
# 서울특별시 종로구 (1111000000)        0.003565  0.003111  0.003689  0.004612
# 서울특별시 종로구 청운효자동(1111051500)   0.004422  0.005666  0.005256  0.005888
# 서울특별시 종로구 사직동(1111053000)     0.004778  0.005550  0.005456  0.006721
# 서울특별시 종로구 삼청동(1111054000)     0.002810  0.001214  0.002487  0.002855
# ...                                ...       ...       ...       ...
# 제주특별자치도 서귀포시 서홍동(5013058000)  0.010099  0.010181  0.011772  0.011197
# 제주특별자치도 서귀포시 대륜동(5013059000)  0.008811  0.009354  0.009132  0.008441
# 제주특별자치도 서귀포시 대천동(5013060000)  0.012066  0.010777  0.011387  0.009940
# 제주특별자치도 서귀포시 중문동(5013061000)  0.007094  0.007124  0.006441  0.010103
# 제주특별자치도 서귀포시 예래동(5013062000)  0.004650  0.005176  0.003167  0.007497
#
#                                     8세        9세  ...       91세       92세  \
# 행정구역                                              ...
# 서울특별시  (1100000000)           0.005707  0.005174  ...  0.000358  0.000293
# 서울특별시 종로구 (1111000000)        0.004157  0.004079  ...  0.000855  0.000498
# 서울특별시 종로구 청운효자동(1111051500)   0.006688  0.006558  ...  0.000533 -0.000043
# 서울특별시 종로구 사직동(1111053000)     0.005018  0.004572  ...  0.001827  0.000696
# 서울특별시 종로구 삼청동(1111054000)     0.001105  0.003287  ...  0.000243  0.002217
# ...                                ...       ...  ...       ...       ...
# 제주특별자치도 서귀포시 서홍동(5013058000)  0.011958  0.011866  ...  0.000561  0.000408
# 제주특별자치도 서귀포시 대륜동(5013059000)  0.009083  0.008874  ... -0.000009  0.000125
# 제주특별자치도 서귀포시 대천동(5013060000)  0.010753  0.008978  ... -0.000131  0.000799
# 제주특별자치도 서귀포시 중문동(5013061000)  0.007664  0.010215  ...  0.000553  0.000426
# 제주특별자치도 서귀포시 예래동(5013062000)  0.004785  0.003513  ...  0.001035  0.000915
#
#                                    93세       94세       95세       96세  \
# 행정구역
# 서울특별시  (1100000000)           0.000227  0.000124 -0.000057  0.000043
# 서울특별시 종로구 (1111000000)        0.000541  0.000440  0.000164  0.000232
# 서울특별시 종로구 청운효자동(1111051500)   0.000363  0.000486  0.000239  0.000452
# 서울특별시 종로구 사직동(1111053000)     0.000680  0.001252  0.000214  0.000032
# 서울특별시 종로구 삼청동(1111054000)     0.001203  0.000144  0.000422  0.000189
# ...                                ...       ...       ...       ...
# 제주특별자치도 서귀포시 서홍동(5013058000) -0.000269  0.000255 -0.000314 -0.000084
# 제주특별자치도 서귀포시 대륜동(5013059000)  0.000146  0.000052 -0.000106  0.000166
# 제주특별자치도 서귀포시 대천동(5013060000)  0.000093  0.000065 -0.000097 -0.000035
# 제주특별자치도 서귀포시 중문동(5013061000)  0.000167  0.000125 -0.000139  0.000257
# 제주특별자치도 서귀포시 예래동(5013062000)  0.001259  0.000540  0.000450 -0.000179
#
#                                    97세       98세       99세   100세 이상
# 행정구역
# 서울특별시  (1100000000)           0.000118  0.000009  0.000013 -0.000317
# 서울특별시 종로구 (1111000000)        0.000309  0.000244  0.000123  0.000786
# 서울특별시 종로구 청운효자동(1111051500)   0.000384  0.000181  0.000068  0.000514
# 서울특별시 종로구 사직동(1111053000)     0.000754 -0.000029  0.000227  0.001018
# 서울특별시 종로구 삼청동(1111054000)     0.001014 -0.000134  0.000278  0.001957
# ...                                ...       ...       ...       ...
# 제주특별자치도 서귀포시 서홍동(5013058000)  0.000102  0.000057  0.000006 -0.000795
# 제주특별자치도 서귀포시 대륜동(5013059000)  0.000463  0.000004  0.000049 -0.000572
# 제주특별자치도 서귀포시 대천동(5013060000) -0.000017  0.000155 -0.000017 -0.000769
# 제주특별자치도 서귀포시 중문동(5013061000) -0.000002  0.000127 -0.000002 -0.000376
# 제주특별자치도 서귀포시 예래동(5013062000)  0.001439  0.000375 -0.000090  0.000033
#
# [3823 rows x 101 columns]

# %%
z
# Out:
# 행정구역
# 서울특별시  (1100000000)             0.009998
# 서울특별시 종로구 (1111000000)          0.009974
# 서울특별시 종로구 청운효자동(1111051500)     0.012189
# 서울특별시 종로구 사직동(1111053000)       0.011473
# 서울특별시 종로구 삼청동(1111054000)       0.012007
#                                   ...
# 제주특별자치도 서귀포시 서홍동(5013058000)    0.014765
# 제주특별자치도 서귀포시 대륜동(5013059000)    0.013972
# 제주특별자치도 서귀포시 대천동(5013060000)    0.014156
# 제주특별자치도 서귀포시 중문동(5013061000)    0.013395
# 제주특별자치도 서귀포시 예래동(5013062000)    0.012634
# Length: 3823, dtype: float64

# %%
df2.iloc[0,:10]
# Out:
# 0세    0.001883
# 1세    0.001435
# 2세    0.001659
# 3세    0.001883
# 4세    0.001972
# 5세    0.002466
# 6세    0.001928
# 7세    0.001928
# 8세    0.001838
# 9세    0.002600
# Name: 서울특별시 광진구 화양동(1121571000), dtype: float64

# %%
# 4 │ ➊ 궁금한 지역 A의 인구 비율에서 B의 인구 비율을 뺀다.
x = df.sub(df2.iloc[0], axis=1)
# 4 │ ➋. A의 인구 비율에서 B의 인구 비율을 뺀 값의 제곱값을 모두 더한다.
y = np.power(x, 2)
z = y.sum(axis=1)
i = z.sort_values().index[:5]     # 4 │ ➌ 그 차이가 가장 작은 지역 5곳을 찾는다.
df.loc[i].T.plot()                # 4 │ ➍ 결과를 꺾은선 그래프로 보여준다.

# %%
df.loc[np.power(df.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[:5]].T.plot()                # 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
plt.rc('font', family='Malgun Gothic')
df = pd.read_csv('age.csv', encoding='cp949', index_col=0)
df = df.div(df['총인구수'], axis=0)
del df['총인구수'], df['연령구간인구수']
 
name = input('원하는 지역의 이름을 입력해주세요 : ')
a = df.index.str.contains(name)
df2 = df[a]
 
df.loc[np.power(df.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[:10]].T.plot()
 
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 화양동

# %%
ㅇㄹㄴㅁㅇㄻㄴㅇㄻㄴㅇㄹ
